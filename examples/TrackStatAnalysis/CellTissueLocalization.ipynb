# %%
import sys
sys.path.append('../')
import numpy as np
import os
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import napari
import seaborn as sns
import napatrackmater.bTrackmate as TM
from pathlib import Path
# %gui qt

# %%
#Trackmate writes an XML file of tracks, we use it as input
xml_path = '/Users/aimachine/MariTests/spot_visualization_test/t1_20.xml' 
Image = None #'/Users/aimachine/Claudia_Tracking/105E_RawImage.tif'
MaskImage = None #'/Users/aimachine/Claudia_Tracking/105E_Mask.tif'

# %%
Gradients = TM.import_TM_XML_Localization(xml_path, Image, MaskImage)
# Out:
# All Tracks plot
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 655/655 [00:02<00:00, 286.28it/s]

# %%
sns.histplot(Gradients, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>
