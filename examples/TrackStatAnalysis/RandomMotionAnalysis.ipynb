# %%
import sys
sys.path.append('../')
import numpy as np
import os
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import napari
import napatrackmater.bTrackmate as TM
from pathlib import Path
# %gui qt

# %%
#Trackmate writes an XML file of tracks, we use it as input
xml_path = '/Users/aimachine/MariTests/spot_visualization_test/t1_20.xml'

# %%
TM.import_TM_XML_Randomization(xml_path)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 4286.06it/s]
# Gaussfits for trackid:  10
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  11
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  12
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  13
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  14
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  18
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  199
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  205
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  208
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  218
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  220
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  234
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  235
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  25
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  27
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  28
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  3
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  30
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  41
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  66
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  72
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
# Gaussfits for trackid:  9
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 62.2904223
#     reduced chi-square = 8.89863176
#     Akaike info crit   = 24.2922259
#     Bayesian info crit = 25.1999811
# [[Variables]]
#     amp:  1113.05084 +/- 11.3096417 (1.02%) (init = 1000)
#     mu:  -2.74883404 +/- 0.04003851 (1.46%) (init = -0.009592326)
#     std:  12.3723150 +/- 0.28282861 (2.29%) (init = 2.947975)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 0.945
#     C(amp, std) = -0.930
#     C(mu, std)  = -0.920
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 1522798.00
#     reduced chi-square = 217542.571
#     Akaike info crit   = 125.334749
#     Bayesian info crit = 126.242504
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     amp:  5176.11911 (init = 1234)
#     mu:   1.55038558 (init = -0.1567949)
#     std:  24.6737958 (init = 20.62389)
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 206160.001
#     reduced chi-square = 29451.4287
#     Akaike info crit   = 105.338228
#     Bayesian info crit = 106.245983
# ##  Warning: uncertainties could not be estimated:
#     amp:  at initial value
# [[Variables]]
#     amp:  783.000000 +/- 1.5579e+10 (1989682528.92%) (init = 783)
#     mu:  -0.40127369 +/- 2.1284e+09 (530420034606.44%) (init = 0.04645774)
#     std:  5.93074225 +/-        nan (nan%) (init = 6.028602)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.655
