# %%
import sys
sys.path.append('../../')
import numpy as np
import os
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import napari
import napatrackmater.bTrackmate as TM
from pathlib import Path
# %gui qt

# %%
#Trackmate writes an XML file of tracks, we use it as input
xml_path = '/Users/aimachine/CBIAS-Demo/DUP_105E_RawImage.xml'
nbins = 10

# %%
TM.import_TM_XML_Randomization(xml_path, nbins = nbins)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 6309.38it/s]
# Gaussfits for trackid:  10
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 22
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 291.000000
#     reduced chi-square = 41.5714286
#     Akaike info crit   = 39.7073817
#     Bayesian info crit = 40.6151370
# [[Variables]]
#     amp:  47.0005946 +/- 1683.50514 (3581.88%) (init = 47)
#     mu:  -0.59914039 +/- 1216.79114 (203089.48%) (init = 0)
#     std:  0.05840833 +/- 171.356625 (293377.01%) (init = 1.870829)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.000
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 57.9299769
#     reduced chi-square = 8.27571099
#     Akaike info crit   = 23.5664989
#     Bayesian info crit = 24.4742542
# [[Variables]]
#     amp:  16.8013791 +/- 2.05366192 (12.22%) (init = 20)
#     mu:   0.13874052 +/- 0.13484355 (97.19%) (init = 0.3099084)
#     std:  1.83001971 +/- 0.52410904 (28.64%) (init = 1.014728)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.582
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 61
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 109.049113
#     reduced chi-square = 15.5784447
#     Akaike info crit   = 29.8921327
#     Bayesian info crit = 30.7998879
# [[Variables]]
#     amp:  21.5028479 +/- 3.32912752 (15.48%) (init = 26)
#     mu:  -0.37794115 +/- 0.14347405 (37.96%) (init = 0.3027012)
#     std:  1.28808434 +/- 0.46069740 (35.77%) (init = 1.225389)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Gaussfits for trackid:  11
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 35
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 317.000000
#     reduced chi-square = 45.2857143
#     Akaike info crit   = 40.5631668
#     Bayesian info crit = 41.4709221
# [[Variables]]
#     amp:  42.0000122 +/- 7915.58743 (18846.63%) (init = 42)
#     mu:  -7.7660e-05 +/- 25429.5071 (32744732560.36%) (init = 0.1343284)
#     std:  0.02071000 +/- 1870.10583 (9029964.03%) (init = 1.827612)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -1.000
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 5.03655458
#     reduced chi-square = 0.71950780
#     Akaike info crit   = -0.85862859
#     Bayesian info crit = 0.04912669
# [[Variables]]
#     amp:  22.0081416 +/- 0.72008651 (3.27%) (init = 21)
#     mu:  -0.05569548 +/- 0.03463362 (62.18%) (init = 0.1626454)
#     std:  1.68404807 +/- 0.12795108 (7.60%) (init = 1.210207)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.580
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 49
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 127.370097
#     reduced chi-square = 18.1957281
#     Akaike info crit   = 31.4451191
#     Bayesian info crit = 32.3528743
# [[Variables]]
#     amp:  30.5634694 +/- 4.29381586 (14.05%) (init = 31)
#     mu:  -0.15089605 +/- 0.11163660 (73.98%) (init = 0.2400956)
#     std:  0.61828816 +/- 0.18492574 (29.91%) (init = 1.183747)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.432
#     C(mu, std)  = 0.106
# Gaussfits for trackid:  12
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 24
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 200.000000
#     reduced chi-square = 28.5714286
#     Akaike info crit   = 35.9573227
#     Bayesian info crit = 36.8650780
# [[Variables]]
#     amp:  30.0345317 +/- 24238272.7 (80701350.60%) (init = 30)
#     mu:  -0.00442023 +/- 1582940.51 (35811244218.83%) (init = 0)
#     std:  0.01697347 +/- 93449.0109 (550559141.54%) (init = 1.897367)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -0.538
#     C(mu, std)  = 0.533
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 145
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 58.0450091
#     reduced chi-square = 8.29214415
#     Akaike info crit   = 23.5863364
#     Bayesian info crit = 24.4940916
# [[Variables]]
#     amp:  12.3693442 +/- 2.39505529 (19.36%) (init = 13)
#     mu:  -0.34040521 +/- 0.11361211 (33.38%) (init = 0.3736197)
#     std:  0.51646304 +/- 0.23123261 (44.77%) (init = 0.9226793)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 78.6753159
#     reduced chi-square = 11.2393308
#     Akaike info crit   = 26.6274437
#     Bayesian info crit = 27.5351989
# [[Variables]]
#     amp:  15.5283123 +/- 2.72593959 (17.55%) (init = 19)
#     mu:  -0.19596938 +/- 0.22893613 (116.82%) (init = 0.2283232)
#     std:  2.55252724 +/- 1.03503797 (40.55%) (init = 1.275986)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Gaussfits for trackid:  13
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 101.277189
#     reduced chi-square = 14.4681699
#     Akaike info crit   = 29.1527611
#     Bayesian info crit = 30.0605164
# [[Variables]]
#     amp:  22.9064208 +/- 3.65268700 (15.95%) (init = 21)
#     mu:   0.21490200 +/- 0.15883208 (73.91%) (init = 1.549336)
#     std:  1.52354122 +/- 0.56755953 (37.25%) (init = 1.792206)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.587
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 20.3489551
#     reduced chi-square = 2.90699359
#     Akaike info crit   = 13.1044447
#     Bayesian info crit = 14.0122000
# [[Variables]]
#     amp:  22.1154407 +/- 1.42673086 (6.45%) (init = 22)
#     mu:   0.18853797 +/- 0.08875980 (47.08%) (init = 0.5115032)
#     std:  2.83943701 +/- 0.42295810 (14.90%) (init = 1.523007)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Gaussfits for trackid:  14
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 340.000003
#     reduced chi-square = 48.5714290
#     Akaike info crit   = 41.2636053
#     Bayesian info crit = 42.1713606
# [[Variables]]
#     amp:  38.0100477 +/- 275.067298 (723.67%) (init = 38)
#     mu:  -0.00303922 +/- 41.5337720 (1366595.08%) (init = -0.09375)
#     std:  0.03493779 +/- 5.44056997 (15572.16%) (init = 1.909833)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -0.200
#     C(mu, std)  = 0.195
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 29.2937250
#     reduced chi-square = 4.18481786
#     Akaike info crit   = 16.7478824
#     Bayesian info crit = 17.6556376
# [[Variables]]
#     amp:  17.4328470 +/- 1.60291944 (9.19%) (init = 18)
#     mu:   0.17926001 +/- 0.15190960 (84.74%) (init = 0.6405373)
#     std:  4.09542860 +/- 0.86989754 (21.24%) (init = 1.773407)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 25.0354575
#     reduced chi-square = 3.57649393
#     Akaike info crit   = 15.1770803
#     Bayesian info crit = 16.0848356
# [[Variables]]
#     amp:  15.9979580 +/- 1.41968912 (8.87%) (init = 19)
#     mu:  -0.83550160 +/- 0.14776591 (17.69%) (init = 0.08918874)
#     std:  3.92940007 +/- 0.91003638 (23.16%) (init = 1.680366)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.602
#     C(mu, std)  = -0.166
# Gaussfits for trackid:  18
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 446.000001
#     reduced chi-square = 63.7142858
#     Akaike info crit   = 43.9773386
#     Bayesian info crit = 44.8850939
# [[Variables]]
#     amp:  39.0000232 +/- 32.0054764 (82.07%) (init = 39)
#     mu:  -0.29979153 +/- 139.349601 (46482.17%) (init = -0.2608696)
#     std:  0.07310951 +/- 25.1641871 (34419.85%) (init = 2.151186)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 0.968
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 14.0110606
#     reduced chi-square = 2.00158008
#     Akaike info crit   = 9.37261966
#     Bayesian info crit = 10.2803749
# [[Variables]]
#     amp:  15.8586462 +/- 1.01394201 (6.39%) (init = 16)
#     mu:   0.37732070 +/- 0.13261548 (35.15%) (init = 0.9325453)
#     std:  6.45684876 +/- 0.95418091 (14.78%) (init = 2.04456)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 48.4026994
#     reduced chi-square = 6.91467135
#     Akaike info crit   = 21.7697049
#     Bayesian info crit = 22.6774602
# [[Variables]]
#     amp:  12.2549007 +/- 1.62461645 (13.26%) (init = 15)
#     mu:   0.02458823 +/- 0.27040419 (1099.73%) (init = 0.5339574)
#     std:  6.27263333 +/- 2.00292457 (31.93%) (init = 1.71075)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.591
# Gaussfits for trackid:  199
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 703.000002
#     reduced chi-square = 100.428572
#     Akaike info crit   = 48.5277180
#     Bayesian info crit = 49.4354733
# [[Variables]]
#     amp:  29.0008293 +/- 131.365838 (452.97%) (init = 29)
#     mu:  -0.00249683 +/- 197.153369 (7896138.15%) (init = -0.1666667)
#     std:  0.21800354 +/- 64.3121296 (29500.50%) (init = 2.867442)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -0.997
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 53
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 60.0454248
#     reduced chi-square = 8.57791782
#     Akaike info crit   = 23.9251626
#     Bayesian info crit = 24.8329179
# [[Variables]]
#     amp:  14.5577968 +/- 1.99616549 (13.71%) (init = 17)
#     mu:  -0.23878546 +/- 0.24724237 (103.54%) (init = -0.1081076)
#     std:  4.84485871 +/- 1.61732403 (33.38%) (init = 1.810636)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.592
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 46.4467480
#     reduced chi-square = 6.63524972
#     Akaike info crit   = 21.3572136
#     Bayesian info crit = 22.2649689
# [[Variables]]
#     amp:  15.7844407 +/- 1.78741749 (11.32%) (init = 17)
#     mu:  -0.17626616 +/- 0.15525224 (88.08%) (init = 0.1225219)
#     std:  2.82190357 +/- 0.74005727 (26.23%) (init = 1.376155)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Gaussfits for trackid:  205
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 45
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 68.9528271
#     reduced chi-square = 9.85040388
#     Akaike info crit   = 25.3083751
#     Bayesian info crit = 26.2161304
# [[Variables]]
#     amp:  15.9328564 +/- 2.29445957 (14.40%) (init = 20)
#     mu:  -0.06417516 +/- 0.21897103 (341.21%) (init = 0.6304708)
#     std:  3.47254566 +/- 1.15835862 (33.36%) (init = 1.692412)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.579
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 37
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 34.1190748
#     reduced chi-square = 4.87415354
#     Akaike info crit   = 18.2727151
#     Bayesian info crit = 19.1804704
# [[Variables]]
#     amp:  19.0302795 +/- 1.79166751 (9.41%) (init = 21)
#     mu:  -0.36684401 +/- 0.13048169 (35.57%) (init = -0.07896553)
#     std:  2.88152130 +/- 0.62647177 (21.74%) (init = 1.786675)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Gaussfits for trackid:  208
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 157.000001
#     reduced chi-square = 22.4285715
#     Akaike info crit   = 33.5366072
#     Bayesian info crit = 34.4443625
# [[Variables]]
#     amp:  42.0038774 +/- 232.287747 (553.02%) (init = 42)
#     mu:   0.00432786 +/- 129.555917 (2993536.25%) (init = -0.3230769)
#     std:  0.20289750 +/- 38.9835808 (19213.44%) (init = 2.637643)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 1.000
#     C(amp, std) = -0.124
#     C(mu, std)  = -0.121
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 81
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 106.871483
#     reduced chi-square = 15.2673547
#     Akaike info crit   = 29.6904193
#     Bayesian info crit = 30.5981745
# [[Variables]]
#     amp:  24.4553939 +/- 3.96787210 (16.22%) (init = 25)
#     mu:  -0.31554333 +/- 0.19120653 (60.60%) (init = 0.6945495)
#     std:  1.74732221 +/- 0.62505612 (35.77%) (init = 2.42257)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.517
#     C(mu, std)  = 0.118
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 45
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 51.4382471
#     reduced chi-square = 7.34832101
#     Akaike info crit   = 22.3779691
#     Bayesian info crit = 23.2857244
# [[Variables]]
#     amp:  13.5078933 +/- 1.89636804 (14.04%) (init = 16)
#     mu:  -0.30237342 +/- 0.22621835 (74.81%) (init = 0.3173373)
#     std:  3.90225661 +/- 1.27300276 (32.62%) (init = 1.783267)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.580
# Gaussfits for trackid:  218
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 166
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 25.0000102
#     reduced chi-square = 3.57143003
#     Akaike info crit   = 15.1629114
#     Bayesian info crit = 16.0706667
# [[Variables]]
#     amp:  51.6047489 +/- 3222.04033 (6243.69%) (init = 31)
#     mu:  -2.12449644 +/- 22.0634054 (1038.52%) (init = -0.2)
#     std:  0.76523619 +/- 39.6790548 (5185.20%) (init = 3.815757)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -1.000
#     C(mu, std)  = 1.000
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 26
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 3.06394367
#     reduced chi-square = 0.43770624
#     Akaike info crit   = -5.82882226
#     Bayesian info crit = -4.92106698
# [[Variables]]
#     amp:  32.7484131 +/- 2.76236603 (8.44%) (init = 25)
#     mu:  -1.36802564 +/- 0.10596826 (7.75%) (init = 0.7120685)
#     std:  9.82119623 +/- 1.80561982 (18.38%) (init = 5.081137)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.963
#     C(mu, std)  = 0.848
#     C(amp, mu)  = -0.845
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 13.4050393
#     reduced chi-square = 1.91500561
#     Akaike info crit   = 8.93045607
#     Bayesian info crit = 9.83821135
# [[Variables]]
#     amp:  18.5833748 +/- 1.36633569 (7.35%) (init = 19)
#     mu:  -1.08340083 +/- 0.14661707 (13.53%) (init = -0.1960351)
#     std:  5.38448306 +/- 0.88008838 (16.34%) (init = 3.293664)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.537
# Gaussfits for trackid:  220
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 136.000000
#     reduced chi-square = 19.4285715
#     Akaike info crit   = 32.1006980
#     Bayesian info crit = 33.0084532
# [[Variables]]
#     amp:  48.0011494 +/- 172.164396 (358.67%) (init = 48)
#     mu:   0.00215897 +/- 161.615210 (7485766.33%) (init = -0.3529412)
#     std:  0.19465175 +/- 46.3915196 (23833.09%) (init = 2.331149)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.000
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 6.77217492
#     reduced chi-square = 0.96745356
#     Akaike info crit   = 2.10237200
#     Bayesian info crit = 3.01012728
# [[Variables]]
#     amp:  28.1289011 +/- 0.93680305 (3.33%) (init = 26)
#     mu:  -0.02580700 +/- 0.05562771 (215.55%) (init = 0.9144628)
#     std:  4.27254624 +/- 0.33960395 (7.95%) (init = 2.034576)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.593
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 71.8324706
#     reduced chi-square = 10.2617815
#     Akaike info crit   = 25.7175152
#     Bayesian info crit = 26.6252705
# [[Variables]]
#     amp:  12.8311862 +/- 2.03827673 (15.89%) (init = 16)
#     mu:  -0.62414081 +/- 0.29950078 (47.99%) (init = -0.09538903)
#     std:  5.32465265 +/- 2.04245023 (38.36%) (init = 1.648991)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.590
# Gaussfits for trackid:  234
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 274.000000
#     reduced chi-square = 39.1428572
#     Akaike info crit   = 39.1054302
#     Bayesian info crit = 40.0131854
# [[Variables]]
#     amp:  45.0001794 +/- 87.1314624 (193.62%) (init = 45)
#     mu:  -0.60053178 +/- 128.827269 (21452.20%) (init = -0.2112676)
#     std:  0.07094718 +/- 22.4934693 (31704.53%) (init = 2.095706)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -0.997
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 42.2445167
#     reduced chi-square = 6.03493096
#     Akaike info crit   = 20.4088947
#     Bayesian info crit = 21.3166500
# [[Variables]]
#     amp:  15.5050088 +/- 1.68117492 (10.84%) (init = 17)
#     mu:  -0.50177646 +/- 0.20968320 (41.79%) (init = -0.2180423)
#     std:  5.62269182 +/- 1.43593815 (25.54%) (init = 1.701527)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.584
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 49
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 48.1145683
#     reduced chi-square = 6.87350976
#     Akaike info crit   = 21.7099991
#     Bayesian info crit = 22.6177544
# [[Variables]]
#     amp:  18.2304239 +/- 1.99473221 (10.94%) (init = 20)
#     mu:   0.08368643 +/- 0.12798104 (152.93%) (init = 0.3057465)
#     std:  2.05455338 +/- 0.52056424 (25.34%) (init = 1.217471)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Gaussfits for trackid:  235
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 149.000001
#     reduced chi-square = 21.2857144
#     Akaike info crit   = 33.0136122
#     Bayesian info crit = 33.9213675
# [[Variables]]
#     amp:  53.0000822 +/- 34.8232755 (65.70%) (init = 53)
#     mu:  -0.30033409 +/- 70.0925235 (23338.18%) (init = 0.125)
#     std:  0.07191547 +/- 12.4254943 (17277.91%) (init = 1.763342)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -0.991
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 17.1524903
#     reduced chi-square = 2.45035575
#     Akaike info crit   = 11.3955828
#     Bayesian info crit = 12.3033380
# [[Variables]]
#     amp:  22.3403687 +/- 1.28271814 (5.74%) (init = 23)
#     mu:  -0.75849917 +/- 0.11996402 (15.82%) (init = -0.1093088)
#     std:  6.54723501 +/- 0.86821350 (13.26%) (init = 2.12791)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 37
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 49.7012713
#     reduced chi-square = 7.10018162
#     Akaike info crit   = 22.0344542
#     Bayesian info crit = 22.9422095
# [[Variables]]
#     amp:  22.4680695 +/- 2.25625307 (10.04%) (init = 23)
#     mu:  -0.38003556 +/- 0.16809427 (44.23%) (init = -0.246245)
#     std:  4.20397702 +/- 0.97497741 (23.19%) (init = 1.989736)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Gaussfits for trackid:  25
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 614.000001
#     reduced chi-square = 87.7142858
#     Akaike info crit   = 47.1740984
#     Bayesian info crit = 48.0818536
# [[Variables]]
#     amp:  30.0000863 +/- 60.9608863 (203.20%) (init = 30)
#     mu:  -0.60046487 +/- 162.238664 (27018.84%) (init = -0.5454545)
#     std:  0.07512315 +/- 30.2099357 (40213.89%) (init = 2.330183)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = -0.988
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 45
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 99.7921319
#     reduced chi-square = 14.2560188
#     Akaike info crit   = 29.0050425
#     Bayesian info crit = 29.9127978
# [[Variables]]
#     amp:  18.1989175 +/- 3.02077097 (16.60%) (init = 22)
#     mu:   0.24197666 +/- 0.21039088 (86.95%) (init = 0.4088432)
#     std:  2.41039741 +/- 0.92384026 (38.33%) (init = 1.499385)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.577
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 76.0953263
#     reduced chi-square = 10.8707609
#     Akaike info crit   = 26.2940176
#     Bayesian info crit = 27.2017728
# [[Variables]]
#     amp:  14.4862114 +/- 2.42104519 (16.71%) (init = 17)
#     mu:   0.21922531 +/- 0.16176745 (73.79%) (init = -0.08648605)
#     std:  1.39902021 +/- 0.56690790 (40.52%) (init = 1.11947)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.591
# Gaussfits for trackid:  27
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 22
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 116.000000
#     reduced chi-square = 16.5714286
#     Akaike info crit   = 30.5100510
#     Bayesian info crit = 31.4178063
# [[Variables]]
#     amp:  24.0014281 +/- 221.258383 (921.86%) (init = 24)
#     mu:   0.00136912 +/- 106.009568 (7742888.12%) (init = -0.4736842)
#     std:  0.03150302 +/- 12.3327174 (39147.73%) (init = 1.758241)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 1.000
#     C(amp, std) = -0.101
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 43.2830750
#     reduced chi-square = 6.18329643
#     Akaike info crit   = 20.6517659
#     Bayesian info crit = 21.5595212
# [[Variables]]
#     amp:  5.38081202 +/- 1.36911679 (25.44%) (init = 8)
#     mu:   0.67637448 +/- 0.40923307 (60.50%) (init = 0.9695542)
#     std:  3.58695660 +/- 2.79217161 (77.84%) (init = 1.025269)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.637
#     C(mu, std)  = -0.114
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 37
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 13.5428619
#     reduced chi-square = 1.93469456
#     Akaike info crit   = 9.03274519
#     Bayesian info crit = 9.94050047
# [[Variables]]
#     amp:  9.48354543 +/- 1.05137367 (11.09%) (init = 11)
#     mu:  -0.03086681 +/- 0.08865463 (287.22%) (init = 0.2184911)
#     std:  0.95987339 +/- 0.24630837 (25.66%) (init = 0.9862398)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Gaussfits for trackid:  28
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 34
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 25.0000001
#     reduced chi-square = 3.57142858
#     Akaike info crit   = 15.1629073
#     Bayesian info crit = 16.0706626
# [[Variables]]
#     amp:  14.0040950 +/- 184.986784 (1320.95%) (init = 14)
#     mu:   0.00306595 +/- 69.1483002 (2255365.15%) (init = -0.1428571)
#     std:  0.03214149 +/- 8.24393181 (25648.88%) (init = 1.726149)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 1.000
#     C(amp, std) = -0.220
#     C(mu, std)  = -0.214
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 37
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 30.4404105
#     reduced chi-square = 4.34863007
#     Akaike info crit   = 17.1318592
#     Bayesian info crit = 18.0396145
# [[Variables]]
#     amp:  4.10990346 +/- 1.36545200 (33.22%) (init = 6)
#     mu:  -0.64490933 +/- 0.48617890 (75.39%) (init = -0.2965236)
#     std:  3.19195768 +/- 2.57835850 (80.78%) (init = 1.392135)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.591
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 22.5422303
#     reduced chi-square = 3.22031861
#     Akaike info crit   = 14.1280536
#     Bayesian info crit = 15.0358089
# [[Variables]]
#     amp:  2.89669480 +/- 0.96503133 (33.31%) (init = 5)
#     mu:  -0.03932704 +/- 0.57293533 (1456.85%) (init = -0.0741309)
#     std:  3.17826094 +/- 3.69277886 (116.19%) (init = 0.9099298)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.627
#     C(mu, std)  = 0.379
#     C(amp, mu)  = -0.154
# Gaussfits for trackid:  3
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 304.000002
#     reduced chi-square = 43.4285717
#     Akaike info crit   = 40.1444261
#     Bayesian info crit = 41.0521814
# [[Variables]]
#     amp:  44.1045137 +/- 1361.76987 (3087.60%) (init = 44)
#     mu:   0.01778090 +/- 114.609486 (644565.31%) (init = 0.1666667)
#     std:  0.13325848 +/- 28.9123757 (21696.46%) (init = 2.229848)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 1.000
#     C(amp, std) = -0.554
#     C(mu, std)  = -0.542
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 43.7961422
#     reduced chi-square = 6.25659175
#     Akaike info crit   = 20.7696064
#     Bayesian info crit = 21.6773617
# [[Variables]]
#     amp:  17.8409867 +/- 1.83393812 (10.28%) (init = 19)
#     mu:  -0.86097863 +/- 0.16977948 (19.72%) (init = -0.1225219)
#     std:  3.83858397 +/- 1.03573489 (26.98%) (init = 1.387806)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.602
#     C(mu, std)  = -0.175
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 126.326274
#     reduced chi-square = 18.0466105
#     Akaike info crit   = 31.3628294
#     Bayesian info crit = 32.2705847
# [[Variables]]
#     amp:  14.1083235 +/- 2.73462250 (19.38%) (init = 19)
#     mu:  -0.44354617 +/- 0.36582366 (82.48%) (init = -0.2594582)
#     std:  5.32524907 +/- 2.49865942 (46.92%) (init = 1.512888)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.591
# Gaussfits for trackid:  30
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 47
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 102.000006
#     reduced chi-square = 14.5714294
#     Akaike info crit   = 29.2238777
#     Bayesian info crit = 30.1316330
# [[Variables]]
#     amp:  83.7708762 +/- 15362.8062 (18339.08%) (init = 42)
#     mu:   0.62152664 +/- 39.0111406 (6276.66%) (init = -0.147541)
#     std:  0.55950813 +/- 78.3809765 (14008.91%) (init = 2.267634)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -1.000
#     C(amp, mu)  = 1.000
#     C(mu, std)  = -1.000
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 2.81140335
#     reduced chi-square = 0.40162905
#     Akaike info crit   = -6.68901322
#     Bayesian info crit = -5.78125795
# [[Variables]]
#     amp:  46.4145047 +/- 1.53389477 (3.30%) (init = 41)
#     mu:  -1.85882192 +/- 0.08847362 (4.76%) (init = 0.4834712)
#     std:  8.82791007 +/- 0.69249537 (7.84%) (init = 4.198014)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.881
#     C(mu, std)  = -0.850
#     C(amp, mu)  = 0.843
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 7.06726365
#     reduced chi-square = 1.00960909
#     Akaike info crit   = 2.52888275
#     Bayesian info crit = 3.43663803
# [[Variables]]
#     amp:  29.9787534 +/- 1.18137161 (3.94%) (init = 25)
#     mu:  -0.86520816 +/- 0.06507195 (7.52%) (init = -0.05529436)
#     std:  5.35990962 +/- 0.52579403 (9.81%) (init = 2.84774)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.673
# Gaussfits for trackid:  41
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 29.0000001
#     reduced chi-square = 4.14285716
#     Akaike info crit   = 16.6471074
#     Bayesian info crit = 17.5548627
# [[Variables]]
#     amp:  18.0013611 +/- 108.860659 (604.74%) (init = 18)
#     mu:   0.00155316 +/- 62.0703913 (3996382.44%) (init = -0.36)
#     std:  0.03190152 +/- 7.32457310 (22959.95%) (init = 1.546092)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 1.000
#     C(amp, std) = -0.113
#     C(mu, std)  = -0.111
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 26
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 2.16102831
#     reduced chi-square = 0.30871833
#     Akaike info crit   = -9.32000914
#     Bayesian info crit = -8.41225386
# [[Variables]]
#     amp:  12.0730084 +/- 0.55445127 (4.59%) (init = 12)
#     mu:  -0.06396438 +/- 0.04667272 (72.97%) (init = 0.7057262)
#     std:  1.34865076 +/- 0.14181201 (10.52%) (init = 1.98484)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.534
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 105
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 12.6139436
#     reduced chi-square = 1.80199195
#     Akaike info crit   = 8.32217747
#     Bayesian info crit = 9.22993275
# [[Variables]]
#     amp:  8.38064036 +/- 1.30063479 (15.52%) (init = 9)
#     mu:  -0.29687001 +/- 0.07465152 (25.15%) (init = 0.02075665)
#     std:  0.33001062 +/- 0.11577196 (35.08%) (init = 0.9898116)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.557
# Gaussfits for trackid:  66
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 13.0000000
#     reduced chi-square = 1.85714286
#     Akaike info crit   = 8.62364266
#     Bayesian info crit = 9.53139794
# [[Variables]]
#     amp:  8.00106150 +/- 110.454452 (1380.50%) (init = 8)
#     mu:  -0.00204486 +/- 106.312193 (5198996.77%) (init = 0.2307692)
#     std:  0.03151549 +/- 12.3812574 (39286.26%) (init = 1.846154)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(amp, std) = -0.151
#     C(mu, std)  = 0.147
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 11.8648396
#     reduced chi-square = 1.69497708
#     Akaike info crit   = 7.70994275
#     Bayesian info crit = 8.61769803
# [[Variables]]
#     amp:  1.99832012 +/- 0.75280689 (37.67%) (init = 4)
#     mu:   0.26805166 +/- 0.53403543 (199.23%) (init = 0.2394998)
#     std:  2.64509563 +/- 2.82980360 (106.98%) (init = 1.107642)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.611
#     C(mu, std)  = 0.245
#     C(amp, mu)  = -0.105
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 41
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 5.74425334
#     reduced chi-square = 0.82060762
#     Akaike info crit   = 0.45614844
#     Bayesian info crit = 1.36390371
# [[Variables]]
#     amp:  2.66571597 +/- 0.64307745 (24.12%) (init = 3)
#     mu:  -0.34459077 +/- 0.29243068 (84.86%) (init = 0.1995832)
#     std:  2.20955488 +/- 1.23975386 (56.11%) (init = 1.609586)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.580
# Gaussfits for trackid:  72
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 26
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 5.00000001
#     reduced chi-square = 0.71428572
#     Akaike info crit   = -0.93147178
#     Bayesian info crit = -0.02371650
# [[Variables]]
#     amp:  5.00039830 +/- 35.7324020 (714.59%) (init = 5)
#     mu:   0.00161376 +/- 72.3382903 (4482594.09%) (init = 0.375)
#     std:  0.03269283 +/- 8.77501932 (26840.81%) (init = 1.798437)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = 1.000
#     C(amp, std) = -0.115
#     C(mu, std)  = -0.112
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 157
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 5.60000460
#     reduced chi-square = 0.80000066
#     Akaike info crit   = 0.20182326
#     Bayesian info crit = 1.10957854
# [[Variables]]
#     amp:  0.80033108 +/- 83.7694545 (10466.85%) (init = 2)
#     mu:  -26.4686259 +/- 9193787.42 (34734660.79%) (init = 0.1945936)
#     std:  1478905.41 +/- 8.0477e+11 (54416731.76%) (init = 1.346623)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(mu, std)  = -1.000
#     C(amp, mu)  = -1.000
#     C(amp, std) = 0.998
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 2716
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 3.47768332
#     reduced chi-square = 0.49681190
#     Akaike info crit   = -4.56218735
#     Bayesian info crit = -3.65443207
# [[Variables]]
#     amp:  9037831.07 +/- 1.4170e+11 (1567836.96%) (init = 2)
#     mu:  -264.835270 +/- 258237.738 (97508.82%) (init = 0.3243227)
#     std:  4325.92459 +/- 4215370.86 (97444.39%) (init = 1.346623)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu)  = -1.000
#     C(mu, std)  = -1.000
#     C(amp, std) = 1.000
# Gaussfits for trackid:  9
# Fit in Z [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 13
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 411.000000
#     reduced chi-square = 58.7142857
#     Akaike info crit   = 43.1600812
#     Bayesian info crit = 44.0678365
# [[Variables]]
#     amp:  43.0000954 +/- 7239.55596 (16836.14%) (init = 43)
#     mu:  -0.29966593 +/- 12679.0922 (4231075.65%) (init = -0.1666667)
#     std:  0.05031464 +/- 1518.75010 (3018505.20%) (init = 1.993043)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, mu) = 1.000
# Fit in Y [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 37
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 39.6157199
#     reduced chi-square = 5.65938855
#     Akaike info crit   = 19.7664091
#     Bayesian info crit = 20.6741644
# [[Variables]]
#     amp:  23.2714473 +/- 2.10169945 (9.03%) (init = 22)
#     mu:  -0.29103291 +/- 0.12329858 (42.37%) (init = 0.2810797)
#     std:  2.80085604 +/- 0.58496116 (20.89%) (init = 1.714383)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.578
# Fit in X [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 10
#     # variables        = 3
#     chi-square         = 168.306874
#     reduced chi-square = 24.0438392
#     Akaike info crit   = 34.2320385
#     Bayesian info crit = 35.1397938
# [[Variables]]
#     amp:  27.5712729 +/- 5.46498421 (19.82%) (init = 27)
#     mu:  -0.23115912 +/- 0.19250917 (83.28%) (init = 0.1153147)
#     std:  1.13901831 +/- 0.52101278 (45.74%) (init = 2.237336)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, std) = -0.561
#     C(mu, std)  = 0.334
#     C(amp, mu)  = -0.248
